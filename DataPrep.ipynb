# %%
import pandas as pd

# %%
business =  pd.read_json("../yelp_training_set/yelp_training_set_business.json", lines=True)
reviews = pd.read_json("../yelp_training_set/yelp_training_set_review.json", lines=True)
checkins = pd.read_json("../yelp_training_set/yelp_training_set_checkin.json", lines=True)
users = pd.read_json("../yelp_training_set/yelp_training_set_user.json", lines=True)

# %%
business.head()
# Out:
#               business_id                                         categories  \
# 0  rncjoVoEFUJGCUoC1JgnUA  [Accountants, Professional Services, Tax Servi...
# 1  0FNFSzCFP_rGUoJx8W7tJg                  [Sporting Goods, Bikes, Shopping]
# 2  3f_lyB6vFK48ukH6ScvLHg                                                 []
# 3  usAsSV36QmUej8--yvN-dg                                    [Food, Grocery]
# 4  PzOqRohWw7F7YEPBz6AubA                 [Food, Bagels, Delis, Restaurants]
#
#           city                                       full_address   latitude  \
# 0       Peoria         8466 W Peoria Ave\nSte 6\nPeoria, AZ 85345  33.581867
# 1      Phoenix                  2149 W Wood Dr\nPhoenix, AZ 85029  33.604054
# 2      Phoenix              1134 N Central Ave\nPhoenix, AZ 85004  33.460526
# 3      Phoenix              845 W Southern Ave\nPhoenix, AZ 85041  33.392210
# 4  Glendale Az  6520 W Happy Valley Rd\nSte 101\nGlendale Az, ...  33.712797
#
# ...

# %%
reviews.head()
# Out:
#               business_id       date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg 2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow 2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA 2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg 2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw 2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id                                 votes
# 0  rLtl8ZkDX5vH5nAx9C3q5Q  {'funny': 0, 'useful': 5, 'cool': 2}
# ...

# %%
BUJoin = pd.merge(business, reviews, on="business_id", how="inner")

# %%
BUJoin.head()
# Out:
#               business_id                                         categories  \
# 0  rncjoVoEFUJGCUoC1JgnUA  [Accountants, Professional Services, Tax Servi...
# 1  rncjoVoEFUJGCUoC1JgnUA  [Accountants, Professional Services, Tax Servi...
# 2  rncjoVoEFUJGCUoC1JgnUA  [Accountants, Professional Services, Tax Servi...
# 3  0FNFSzCFP_rGUoJx8W7tJg                  [Sporting Goods, Bikes, Shopping]
# 4  0FNFSzCFP_rGUoJx8W7tJg                  [Sporting Goods, Bikes, Shopping]
#
#       city                                full_address   latitude   longitude  \
# 0   Peoria  8466 W Peoria Ave\nSte 6\nPeoria, AZ 85345  33.581867 -112.241596
# 1   Peoria  8466 W Peoria Ave\nSte 6\nPeoria, AZ 85345  33.581867 -112.241596
# 2   Peoria  8466 W Peoria Ave\nSte 6\nPeoria, AZ 85345  33.581867 -112.241596
# 3  Phoenix           2149 W Wood Dr\nPhoenix, AZ 85029  33.604054 -112.105933
# 4  Phoenix           2149 W Wood Dr\nPhoenix, AZ 85029  33.604054 -112.105933
#
# ...

# %%
BUJoin.categories[1]
# Out:
# ['Accountants', 'Professional Services', 'Tax Services', 'Financial Services']

# %%
uniqueSet= set()
for l in BUJoin.categories:
    uniqueSet.update(l)

# %%
uniqueSet
# Out:
# {'Accessories',
#  'Accountants',
#  'Active Life',
#  'Acupuncture',
#  'Adult',
#  'Adult Education',
#  'Adult Entertainment',
#  'Advertising',
#  'Afghan',
#  'African',
#  'Airlines',
#  'Airport Shuttles',
#  'Airports',
#  'Allergists',
#  'Amateur Sports Teams',
#  'American (New)',
#  'American (Traditional)',
#  'Amusement Parks',
#  'Animal Shelters',
#  'Antiques',
#  'Apartments',
#  'Appliances',
#  'Appliances & Repair',
#  'Aquariums',
#  'Arcades',
#  'Archery',
#  'Architects',
#  'Argentine',
#  'Art Galleries',
#  'Art Schools',
#  'Art Supplies',
#  'Arts & Crafts',
#  'Arts & Entertainment',
#  'Asian Fusion',
#  'Auto Detailing',
#  'Auto Glass Services',
#  'Auto Parts & Supplies',
#  'Auto Repair',
#  'Automotive',
#  'Baby Gear & Furniture',
#  'Bagels',
#  'Bakeries',
#  'Bankruptcy Law',
#  'Banks & Credit Unions',
#  'Barbeque',
#  'Barbers',
#  'Barre Classes',
#  'Bars',
#  'Basque',
#  'Beauty & Spas',
#  'Bed & Breakfast',
#  'Beer, Wine & Spirits',
# ...

# %%
len(uniqueSet)
# Out:
# 508

# %%
BUJoin.to_csv("train.csv", index=False, header=True)

# %%
businessTest =  pd.read_json("../yelp_test_set/yelp_test_set_business.json", lines=True)
reviewsTest = pd.read_json("../yelp_test_set/yelp_test_set_review.json", lines=True)
checkinsTest = pd.read_json("../yelp_test_set/yelp_test_set_checkin.json", lines=True)
usersTest = pd.read_json("../yelp_test_set/yelp_test_set_user.json", lines=True)

# %%
BUJoinTest = pd.merge(businessTest, reviewsTest, on="business_id", how="inner")

# %%
BUJoinTest.head()
# Out:
#               business_id                                         categories  \
# 0  LNdwp-9Isnd6xmBKUz4K_A                  [Burgers, Fast Food, Restaurants]
# 1  LNdwp-9Isnd6xmBKUz4K_A                  [Burgers, Fast Food, Restaurants]
# 2  LNdwp-9Isnd6xmBKUz4K_A                  [Burgers, Fast Food, Restaurants]
# 3  -ZUEwUytc63ZWvgXJz7gHQ  [Women's Clothing, Men's Clothing, Fashion, Sh...
# 4  -ZUEwUytc63ZWvgXJz7gHQ  [Women's Clothing, Men's Clothing, Fashion, Sh...
#
#         city                                  full_address   latitude  \
# 0  Ahwatukee          10823 S 51st St\nAhwatukee, AZ 85044  33.348561
# 1  Ahwatukee          10823 S 51st St\nAhwatukee, AZ 85044  33.348561
# 2  Ahwatukee          10823 S 51st St\nAhwatukee, AZ 85044  33.348561
# 3     Anthem  4250 W Anthem Way\nSte 100\nAnthem, AZ 85086  33.873872
# 4     Anthem  4250 W Anthem Way\nSte 100\nAnthem, AZ 85086  33.873872
#
#     longitude          name neighborhoods  open  review_count  stars_x state  \
# ...

# %%
uniqueSet= set()
for l in BUJoinTest.categories:
    uniqueSet.update(l)
    
len(uniqueSet)
# Out:
# 370

# %%
BUJoinTest.to_csv("test.csv", index=False, header=True)
